# %% [markdown]
# ## Label Encoding & Ordinal Encoding

# %%
# Import Libraries
import pandas as pd 
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %%
# Import Dataset
loc = "C:\\Users\\amira\\Data Science\\0. Some  Basic Work\\07. Preprocessing\\Data\\train.csv"
df = pd.read_csv(loc)
df.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %%
# Display all Row and Col
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# take only two variablesfor LE and OE 
df2 = df[["KitchenQual","BldgType"]]

# %%
df2.head()
# Out:
#   KitchenQual BldgType
# 0          Gd     1Fam
# 1          TA     1Fam
# 2          Gd     1Fam
# 3          Gd     1Fam
# 4          Gd     1Fam

# %% [markdown]
# ### Label Encoding

# %%
# Initialize the Label Enoder
le = LabelEncoder()

# %%
df2["BldgType_L_enc"] = le.fit_transform(df2["BldgType"])
# Out:
# C:\Users\amira\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2[["BldgType_L_enc","BldgType"]]
# Out:
#       BldgType_L_enc BldgType
# 0                  0     1Fam
# 1                  0     1Fam
# 2                  0     1Fam
# 3                  0     1Fam
# 4                  0     1Fam
# 5                  0     1Fam
# 6                  0     1Fam
# 7                  0     1Fam
# 8                  0     1Fam
# 9                  1   2fmCon
# 10                 0     1Fam
# 11                 0     1Fam
# 12                 0     1Fam
# 13                 0     1Fam
# 14                 0     1Fam
# 15                 0     1Fam
# 16                 0     1Fam
# 17                 2   Duplex
# 18                 0     1Fam
# 19                 0     1Fam
# 20                 0     1Fam
# 21                 0     1Fam
# 22                 0     1Fam
# 23                 4   TwnhsE
# 24                 0     1Fam
# 25                 0     1Fam
# 26                 0     1Fam
# 27                 0     1Fam
# 28                 0     1Fam
# 29                 0     1Fam
# ...

# %% [markdown]
# ### Ordinal Encoding

# %%
df["KitchenQual"].value_counts()
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64

# %%
"""# KitchenQual: Kitchen quality

       Ex	Excellent
       Gd	Good
       TA	Typical/Average
       Fa	Fair
"""

# %%
order_Label = {"Ex":4,"Gd":3,"TA":2,"Fa":1}

# %%
df2["KitchenQual_org_enc"] = df2["KitchenQual"].map(order_Label)  # here we create new
# Out:
# C:\Users\amira\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2[["KitchenQual_org_enc", "KitchenQual"]]
# Out:
#       KitchenQual_org_enc KitchenQual
# 0                       3          Gd
# 1                       2          TA
# 2                       3          Gd
# 3                       3          Gd
# 4                       3          Gd
# 5                       2          TA
# 6                       3          Gd
# 7                       2          TA
# 8                       2          TA
# 9                       2          TA
# 10                      2          TA
# 11                      4          Ex
# 12                      2          TA
# 13                      3          Gd
# 14                      2          TA
# 15                      2          TA
# 16                      2          TA
# 17                      2          TA
# 18                      3          Gd
# 19                      2          TA
# 20                      3          Gd
# 21                      3          Gd
# 22                      3          Gd
# 23                      2          TA
# ...
